# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Приоритизация-гипотез-методом-ICE" data-toc-modified-id="Приоритизация-гипотез-методом-ICE-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Приоритизация гипотез методом ICE</a></span></li><li><span><a href="#Приоритизация-гипотез-методом-RICE" data-toc-modified-id="Приоритизация-гипотез-методом-RICE-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Приоритизация гипотез методом RICE</a></span></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Предобработка данных</a></span></li><li><span><a href="#Построим-график-кумулятивной-выручки-по-группам." data-toc-modified-id="Построим-график-кумулятивной-выручки-по-группам.-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Построим график кумулятивной выручки по группам.</a></span></li><li><span><a href="#Построим-график-кумулятивного-среднего-чека-по-группам" data-toc-modified-id="Построим-график-кумулятивного-среднего-чека-по-группам-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Построим график кумулятивного среднего чека по группам</a></span></li><li><span><a href="#Построим-график-относительного-изменения-кумулятивного-среднего-чека-группы-B-к-группе-A" data-toc-modified-id="Построим-график-относительного-изменения-кумулятивного-среднего-чека-группы-B-к-группе-A-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Построим график относительного изменения кумулятивного среднего чека группы B к группе A</a></span></li><li><span><a href="#Построим-график-кумулятивного-среднего-количества-заказов-на-посетителя-по-группам." data-toc-modified-id="Построим-график-кумулятивного-среднего-количества-заказов-на-посетителя-по-группам.-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Построим график кумулятивного среднего количества заказов на посетителя по группам.</a></span></li><li><span><a href="#Постройм-график-относительного-изменения-кумулятивного-среднего-количества-заказов-на-посетителя-группы-B-к-группе-A" data-toc-modified-id="Постройм-график-относительного-изменения-кумулятивного-среднего-количества-заказов-на-посетителя-группы-B-к-группе-A-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Постройм график относительного изменения кумулятивного среднего количества заказов на посетителя группы B к группе A</a></span></li><li><span><a href="#Построим-точечный-график-количества-заказов-по-пользователям." data-toc-modified-id="Построим-точечный-график-количества-заказов-по-пользователям.-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Построим точечный график количества заказов по пользователям.</a></span></li><li><span><a href="#Посчитаем-95-й-и-99-й-перцентили-количества-заказов-на-пользователя" data-toc-modified-id="Посчитаем-95-й-и-99-й-перцентили-количества-заказов-на-пользователя-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>Посчитаем 95-й и 99-й перцентили количества заказов на пользователя</a></span></li><li><span><a href="#Построим-точечный-график-стоимостей-заказов." data-toc-modified-id="Построим-точечный-график-стоимостей-заказов.-11"><span class="toc-item-num">11&nbsp;&nbsp;</span>Построим точечный график стоимостей заказов.</a></span></li><li><span><a href="#Посчитаем-95-й-и-99-й-перцентили-стоимости-заказов" data-toc-modified-id="Посчитаем-95-й-и-99-й-перцентили-стоимости-заказов-12"><span class="toc-item-num">12&nbsp;&nbsp;</span>Посчитаем 95-й и 99-й перцентили стоимости заказов</a></span></li><li><span><a href="#Посчитаем-статистическую-значимость-различий-в-среднем-количестве-заказов-на-посетителя-между-группами-по-«сырым»-данным." data-toc-modified-id="Посчитаем-статистическую-значимость-различий-в-среднем-количестве-заказов-на-посетителя-между-группами-по-«сырым»-данным.-13"><span class="toc-item-num">13&nbsp;&nbsp;</span>Посчитаем статистическую значимость различий в среднем количестве заказов на посетителя между группами по «сырым» данным.</a></span></li><li><span><a href="#Посчитаем-статистическую-значимость-различий-в-среднем-чеке-заказа-между-группами-по-«сырым»-данным." data-toc-modified-id="Посчитаем-статистическую-значимость-различий-в-среднем-чеке-заказа-между-группами-по-«сырым»-данным.-14"><span class="toc-item-num">14&nbsp;&nbsp;</span>Посчитаем статистическую значимость различий в среднем чеке заказа между группами по «сырым» данным.</a></span></li><li><span><a href="#Посчитаем-статистическую-значимость-различий-в-среднем-количестве-заказов-на-посетителя-между-группами-по-«очищенным»-данным" data-toc-modified-id="Посчитаем-статистическую-значимость-различий-в-среднем-количестве-заказов-на-посетителя-между-группами-по-«очищенным»-данным-15"><span class="toc-item-num">15&nbsp;&nbsp;</span>Посчитаем статистическую значимость различий в среднем количестве заказов на посетителя между группами по «очищенным» данным</a></span></li><li><span><a href="#Посчитаем-статистическую-значимость-различий-в-среднем-чеке-заказа-между-группами-по-«очищенным»-данным" data-toc-modified-id="Посчитаем-статистическую-значимость-различий-в-среднем-чеке-заказа-между-группами-по-«очищенным»-данным-16"><span class="toc-item-num">16&nbsp;&nbsp;</span>Посчитаем статистическую значимость различий в среднем чеке заказа между группами по «очищенным» данным</a></span></li><li><span><a href="#Выводы-по-проекту-и-рекомендации." data-toc-modified-id="Выводы-по-проекту-и-рекомендации.-17"><span class="toc-item-num">17&nbsp;&nbsp;</span>Выводы по проекту и рекомендации.</a></span></li></ul></div>

# %% [markdown]
# # Приоритизация гипотез и A/B тест крупного интернет-магазина
#
#
# Я аналитик крупного интернет магазина. Вместе с отделом маркетинга мы подготовили список гипотез для увеличения выручки. В данном исследовании мы приоритизируем гипотезы, запустим A/B-тест и проанализируем результаты.
#
# Ход исследования
#
# 1. Откроем файл с 9 гипотезами по увеличению выручки интернет-магазина с указанными параметрами Reach, Impact, Confidence, Effort:
# - Применим фреймворк ICE и RICE для приоритизации гипотез.
# - Отсортируем их по убыванию приоритета.
# - Посмотрим на разницу приоритетов этих методов.
# 2. Проанализируем A/B-тест:
# - построим график кумулятивной выручки по группам. Сделаем выводы и предположения.
# - построим график кумулятивного среднего чека по группам. Сделаем выводы и предположения.
# - построим график относительного изменения кумулятивного среднего чека группы B к группе A. Сделаем выводы и предположения.
# - построим график кумулятивного среднего количества заказов на посетителя по группам. Сделаем выводы и предположения.
# - построим график относительного изменения кумулятивного среднего количества заказов на посетителя группы B к группе A. Сделаем выводы и предположения.
# - построим точечный график количества заказов по пользователям. Сделаем выводы и предположения.
# - Посчитаем 95-й и 99-й перцентили количества заказов на пользователя. Выберем границу для определения аномальных пользователей.
# - построим точечный график стоимостей заказов. Сделаем выводы и предположения.
# - посчитаем 95-й и 99-й перцентили стоимости заказов. Выберем границу для определения аномальных заказов.
# - просчитаем статистическую значимость различий в среднем количестве заказов на посетителя между группами по «сырым» данным. сделаем выводы и предположения.
# - просчитаем статистическую значимость различий в среднем чеке заказа между группами по «сырым» данным. Сделаем выводы и предположения.
# - просчитаем статистическую значимость различий в среднем количестве заказов на посетителя между группами по «очищенным» данным. Сделаем выводы и предположения.
# - просчитаем статистическую значимость различий в среднем чеке заказа между группами по «очищенным» данным. сделаем выводы и предположения.
# - Примим решение по результатам теста и объясните его. Варианты решений:
# 1. Остановить тест, зафиксировать победу одной из групп.
# 2. Остановить тест, зафиксировать отсутствие различий между группами.
# 3. Продолжить тест.
#
# Напишем общий вывод.
# Начнём!

# %% [markdown]
# # Приоритизация гипотез

# %%
# загрузим библиотеки
from scipy import stats as st
import datetime as dt
import pandas as pd
pd.options.mode.chained_assignment = None 
import numpy as np
import math
import matplotlib.pyplot as plt
import seaborn as sns
from math import factorial
import statistics

# %%
# загрузим датафрейм с гипоземи
try:
    data = pd.read_csv('https://code.s3.yandex.net//datasets/hypothesis.csv') 
except:
    data = pd.read_csv('D:/основа/учеба/проеткы/AB тесты/hypothesis.csv')

# %%
#посмотрим на датафрейм
pd.set_option('display.max_colwidth', False)
data
# Out:
#                                                                                                      Hypothesis  \
# 0  Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей
# 1  Запустить собственную службу доставки, что сократит срок доставки заказов
# 2  Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средний чек заказа
# 3  Изменить структура категорий, что увеличит конверсию, т.к. пользователи быстрее найдут нужный товар
# 4  Изменить цвет фона главной страницы, чтобы увеличить вовлеченность пользователей
# 5  Добавить страницу отзывов клиентов о магазине, что позволит увеличить количество заказов
# 6  Показать на главной странице баннеры с актуальными акциями и распродажами, чтобы увеличить конверсию
# 7  Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок
# 8  Запустить акцию, дающую скидку на товар в день рождения
#
# ...

# %%
#сделаем заголовки строчными
data.columns = map(str.lower, data.columns)

# %% [markdown]
# В дальнейшей предобработке датафрейм не нуждается

# %% [markdown]
# ## Приоритизация гипотез методом ICE

# %%
data['ICE'] = round(( data['impact'] * data['confidence']) / data['efforts'],2)
print (data [['hypothesis', 'ICE']].sort_values('ICE', ascending = False))
# Out:
#                                                                                                      hypothesis  \
# 8  Запустить акцию, дающую скидку на товар в день рождения
# 0  Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей
# 7  Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок
# 6  Показать на главной странице баннеры с актуальными акциями и распродажами, чтобы увеличить конверсию
# 2  Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средний чек заказа
# 1  Запустить собственную службу доставки, что сократит срок доставки заказов
# 5  Добавить страницу отзывов клиентов о магазине, что позволит увеличить количество заказов
# 3  Изменить структура категорий, что увеличит конверсию, т.к. пользователи быстрее найдут нужный товар
# 4  Изменить цвет фона главной страницы, чтобы увеличить вовлеченность пользователей
#
#      ICE
# 8  16.20
# ...

# %% [markdown]
# - Гипотеза с акцией на день рождение набрала самый высокий балл из-за максимального эффекта и уверенности в нем, хотя и реализация этого нововедения потребует определенных усилий.
# - Ненамного меньше у гипотез с добавлением двух новых каналов привлечения трафика и формы подписок для базы с клиентами для почтовых рассылок, они и балы набрали похожие.
# - Проигрышные гипотезы - с собственной службой доставок, страницей с отзывами и изменения фона главной таблицы. Если организовать службу доставки очень затрано, то остальные предложения не несут никакой пользы.

# %% [markdown]
# ## Приоритизация гипотез методом RICE

# %%
data['RICE'] = data['reach'] * data['impact'] * data['confidence'] / data['efforts']
print (data[['hypothesis', 'RICE']].sort_values('RICE', ascending = False))
# Out:
#                                                                                                      hypothesis  \
# 7  Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок
# 2  Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средний чек заказа
# 0  Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей
# 6  Показать на главной странице баннеры с актуальными акциями и распродажами, чтобы увеличить конверсию
# 8  Запустить акцию, дающую скидку на товар в день рождения
# 3  Изменить структура категорий, что увеличит конверсию, т.к. пользователи быстрее найдут нужный товар
# 1  Запустить собственную службу доставки, что сократит срок доставки заказов
# 5  Добавить страницу отзывов клиентов о магазине, что позволит увеличить количество заказов
# 4  Изменить цвет фона главной страницы, чтобы увеличить вовлеченность пользователей
#
#     RICE
# 7  112.0
# ...

# %% [markdown]
# Метод Rice показывает другой результат. В лидерах с серьезным отрывом добавление формы пописок для почтовой рассылки. Из таблицы с гипотезами становится понятно почему - охват клиентов оценен в 10 баллов.

# %% [markdown]
# Вывод:
#
# Методы ICE и RICE показали разные результаты:
# - гипотеза "Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок" под номером 7 методом RICE оценена, как самая перспективная с серьзныем отрывом, в отличии от ICE. Все дело в охвате клиентов, которых коснется нововедение. REACH оценен в 10 балов, т.е. коснется всех. Остальные параметры Impact - насколько сильно изменение повлияет на охваченных пользователей, Confidence - асколько мы уверены в оценках других параметров и Efforts - насколько сложно проверить гипотезу, также получили высокие оценки 7, 8 и 5 соотвественно.
# - можно выделить менее привликательные гипотезы, это гипотизы под номером 4 - последнее место в обоих способах оценки. Все параметры получили самые низкие оценки, кроме охвата. Также неэффективными выглядят гипотезы под номерами 5, 1, 3, каким бы методом не оценивались.
# - кроме лидирующей по оценкам гипотезы, можно выделить гипотезу "добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средний чек заказа" (2), "добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей" (0), "показать на главной странице баннеры с актуальными акциями и распродажами, чтобы увеличить конверсию" (6). Они получили увесистые оценки в обоих способах. Они серьезно не проседают по охвату клиентов.
# - Лидер способа оценки ICE гипотеза "запустить акцию, дающую скидку на товар в день рождения" выглядит неудачной в RICE. Всё из-за минимального охвата клиектов. Неудивительно, ведь день рождение бывает всего раз в году :(.

# %% [markdown]
# # Анализ A/B-теста

# %% [markdown]
# ## Предобработка данных

# %%
# загрузим датафреймы с результатми A/B-теста
try:
    visitors = pd.read_csv('https://code.s3.yandex.net///datasets/visitors.csv') 
except:
    visitors = pd.read_csv('D:/основа/учеба/проеткы/AB тесты/visitors.csv')
try:
    orders = pd.read_csv('https://code.s3.yandex.net///datasets/orders.csv') 
except:
    orders = pd.read_csv('D:/основа/учеба/проеткы/AB тесты/orders.csv')

# %% [markdown]
# Посмотрим на датафреймы

# %%
visitors
# Out:
#           date group  visitors
# 0   2019-08-01  A     719
# 1   2019-08-02  A     619
# 2   2019-08-03  A     507
# 3   2019-08-04  A     717
# 4   2019-08-05  A     756
# ..         ... ..     ...
# 57  2019-08-27  B     720
# 58  2019-08-28  B     654
# 59  2019-08-29  B     531
# 60  2019-08-30  B     490
# 61  2019-08-31  B     718
#
# [62 rows x 3 columns]

# %%
orders
# Out:
#       transactionId   visitorId        date  revenue group
# 0     3667963787     3312258926  2019-08-15  1650     B
# 1     2804400009     3642806036  2019-08-15  730      B
# 2     2961555356     4069496402  2019-08-15  400      A
# 3     3797467345     1196621759  2019-08-15  9759     B
# 4     2282983706     2322279887  2019-08-15  2308     B
# ...          ...            ...         ...   ...    ..
# 1192  2662137336     3733762160  2019-08-14  6490     B
# 1193  2203539145     370388673   2019-08-14  3190     A
# 1194  1807773912     573423106   2019-08-14  10550    A
# 1195  1947021204     1614305549  2019-08-14  100      A
# 1196  3936777065     2108080724  2019-08-15  202740   B
#
# [1197 rows x 5 columns]

# %%
#Посмтрим сколько заказов в группах
orders['group'].value_counts()
# Out:
# B    640
# A    557
# Name: group, dtype: int64

# %% [markdown]
# Сделаем предобработку данных.

# %%
#для начала переименуем столбцы для дальнейшей работы
orders.columns = ['orderId','userId','date','revenue','group']

# %%
#приведем даты к нужному формату
orders['date'] = orders['date'].map(
    lambda x: dt.datetime.strptime(x, '%Y-%m-%d')
)

# %%
visitors['date'] = visitors['date'].map(
    lambda x: dt.datetime.strptime(x, '%Y-%m-%d')
)

# %%
#посмотрим на типы данных
visitors.dtypes
# Out:
# date        datetime64[ns]
# group       object
# visitors    int64
# dtype: object

# %%
orders.dtypes
# Out:
# orderId    int64
# userId     int64
# date       datetime64[ns]
# revenue    int64
# group      object
# dtype: object

# %% [markdown]
# С типами данных все в порядке.
# Проверим датафрейм на дубликаты

# %%
visitors[visitors.duplicated ()]
# Out:
# Empty DataFrame
# Columns: [date, group, visitors]
# Index: []

# %%
orders[orders.duplicated ()]
# Out:
# Empty DataFrame
# Columns: [orderId, userId, date, revenue, group]
# Index: []

# %% [markdown]
# Полных дубликатов не обнаружено.
# Поищем пропуски.

# %%
orders.isna().sum()
# Out:
# orderId    0
# userId     0
# date       0
# revenue    0
# group      0
# dtype: int64

# %%
visitors.isna().sum()
# Out:
# date        0
# group       0
# visitors    0
# dtype: int64

# %% [markdown]
# Пропуски также отсутствуют.

# %%
#проверим все ли в порядке с датами 
display((f"{visitors['date'].min()} - минимальная дата привличения клиента."),
       (f"{visitors['date'].max()} - максимальаня дата привличения клиента."))
# Out:
# '2019-08-01 00:00:00 - минимальная дата привличения клиента.'
# '2019-08-31 00:00:00 - максимальаня дата привличения клиента.'

# %%
display((f"{orders['date'].min()} - минимальная дата привличения клиента."),
       (f"{orders['date'].max()} - максимальаня дата привличения клиента."))
# Out:
# '2019-08-01 00:00:00 - минимальная дата привличения клиента.'
# '2019-08-31 00:00:00 - максимальаня дата привличения клиента.'

# %% [markdown]
# Месяц исследования весь август с 1 числа по 31.

# %%
#проверим аномалии
orders['revenue'].hist(bins=20)
plt.xlabel('выручка')
plt.ylabel('частота')
plt.title('гистограма выручки с одного клиента')
plt.show()

# %% [markdown]
# Видим анамально большие выручки. Хорошо бы от них избавится, чтобы они не завышали показатели одной из групп и не искажали тем самым результаты нашего теста. Этим займемся в дальнейшем после анализа сырых данных

# %% [markdown]
# В заключении предобработки проверим не попали ли одинаковые клиенты в две группы одновременно.

# %%
orders.groupby('userId').agg({'group':'nunique'}).sort_values('group',ascending=False).head(60).reset_index()
# Out:
#         userId  group
# 0   2654030115  2
# 1   3891541246  2
# 2   3941795274  2
# 3   1404934699  2
# 4   351125977   2
# 5   3951559397  2
# 6   2927087541  2
# 7   3963646447  2
# 8   2458001652  2
# 9   3972127743  2
# 10  3984495233  2
# 11  2949041841  2
# 12  1959144690  2
# 13  276558944   2
# 14  2954449915  2
# 15  237748145   2
# 16  963407295   2
# 17  1333886533  2
# 18  232979603   2
# 19  4069496402  2
# 20  2378935119  2
# 21  393266494   2
# 22  2579882178  2
# 23  1316129916  2
# 24  1801183820  2
# 25  3656415546  2
# 26  1614305549  2
# 27  1648269707  2
# 28  2686716486  2
# 29  2712142231  2
# 30  2716752286  2
# 31  1668030113  2
# 32  1602967004  2
# 33  3717692402  2
# 34  3766097110  2
# 35  1738359350  2
# 36  2780786433  2
# 37  3803269165  2
# 38  477780734   2
# 39  471551937   2
# 40  2600415354  2
# 41  818047933   2
# 42  457167155   2
# 43  2587333274  2
# 44  2038680547  2
# 45  3957174400  2
# 46  3234906277  2
# 47  1294878855  2
# ...

# %% [markdown]
# Видим, что 58 клиентов попали сразу в две группы. Это ошибка теста, т.к. 1 клиент должен представлять 1 группу. Т.к. у нас нет данных, по которым мы можем определить группу клиента - удалим их.

# %%
#создадим список из таких клиентов и отсеим их
double_group = orders.groupby('userId').agg({'group':'nunique'}).sort_values('group',ascending=False).head(58).reset_index()['userId']

# %%
#проверим получившийся список
double_group.head(60)
# Out:
# 0     2654030115
# 1     3891541246
# 2     3941795274
# 3     1404934699
# 4     351125977
# 5     3951559397
# 6     2927087541
# 7     3963646447
# 8     2458001652
# 9     3972127743
# 10    3984495233
# 11    2949041841
# 12    1959144690
# 13    276558944
# 14    2954449915
# 15    237748145
# 16    963407295
# 17    1333886533
# 18    232979603
# 19    4069496402
# 20    2378935119
# 21    393266494
# 22    2579882178
# 23    1316129916
# 24    1801183820
# 25    3656415546
# 26    1614305549
# 27    1648269707
# 28    2686716486
# 29    2712142231
# 30    2716752286
# 31    1668030113
# 32    1602967004
# 33    3717692402
# 34    3766097110
# 35    1738359350
# 36    2780786433
# 37    3803269165
# 38    477780734
# 39    471551937
# 40    2600415354
# 41    818047933
# 42    457167155
# 43    2587333274
# 44    2038680547
# 45    3957174400
# 46    3234906277
# 47    1294878855
# 48    199603092
# 49    3202540741
# 50    1230306981
# 51    3062433592
# 52    4256040402
# ...

# %%
orders= orders.query('userId not in @double_group')

# %%
orders.groupby('userId').agg({'group':'nunique'}).sort_values('group',ascending=False).reset_index()
# Out:
#          userId  group
# 0    5114589     1
# 1    2908466434  1
# 2    2776274025  1
# 3    2785040378  1
# 4    2785527055  1
# ..          ... ..
# 968  1426761187  1
# 969  1430210707  1
# 970  1438226485  1
# 971  1452540367  1
# 972  4283872382  1
#
# [973 rows x 2 columns]

# %% [markdown]
# теперь нет клиентов участвующих в двух группах

# %%
orders['group'].value_counts()
# Out:
# B    548
# A    468
# Name: group, dtype: int64

# %% [markdown]
# итого осталось 1016 строк с заказами, в группе А - 468 , в группе В -548

# %% [markdown]
# ## Построим график кумулятивной выручки по группам.

# %%
# создаем массив уникальных пар значений дат и групп теста
datesGroups = orders[['date','group']].drop_duplicates()

# %%
#Соберём агрегированные кумулятивные по дням данные о заказах в несколько действий. 
ordersAggregated = datesGroups.apply(lambda x: orders[np.logical_and(orders['date'] <= x['date'], orders['group'] == x['group'])]\
.agg({'date' : 'max', 'group' : 'max', 'orderId' : 'nunique', 'userId' : 'nunique', 'revenue' : 'sum'}), axis=1).sort_values(by=['date','group'])

# %%
#Аналогично получим агрегированные кумулятивные по дням данные о посетителях интернет-магазина
visitorsAggregated = datesGroups.apply(lambda x: visitors[np.logical_and(visitors['date'] <= x['date'], visitors['group'] == x['group'])].agg({'date' : 'max', 'group' : 'max', 'visitors' : 'sum'}), axis=1).sort_values(by=['date','group'])

# %%
#Объединим обе таблицы в одну с понятными названиями столбцов 
#создаем массив уникальных пар значений дат и групп теста
datesGroups = orders[['date','group']].drop_duplicates()

# получаем агрегированные кумулятивные по дням данные о заказах 
ordersAggregated = datesGroups.apply(lambda x: orders[np.logical_and(orders['date'] <= x['date'], orders['group'] == x['group'])].agg({'date' : 'max', 'group' : 'max', 'orderId' : 'nunique', 'userId' : 'nunique', 'revenue' : 'sum'}), axis=1).sort_values(by=['date','group'])

# получаем агрегированные кумулятивные по дням данные о посетителях интернет-магазина 
visitorsAggregated = datesGroups.apply(lambda x: visitors[np.logical_and(visitors['date'] <= x['date'], visitors['group'] == x['group'])].agg({'date' : 'max', 'group' : 'max', 'visitors' : 'sum'}), axis=1).sort_values(by=['date','group'])

# объединяем кумулятивные данные в одной таблице и присваиваем ее столбцам понятные названия
cumulativeData = ordersAggregated.merge(visitorsAggregated, left_on=['date', 'group'], right_on=['date', 'group'])
cumulativeData.columns = ['date', 'group', 'orders', 'buyers', 'revenue', 'visitors']

print(cumulativeData.head(5))
# Out:
#         date group  orders  buyers  revenue  visitors
# 0 2019-08-01  A     23      19      142779   719
# 1 2019-08-01  B     17      17      59758    713
# 2 2019-08-02  A     42      36      234381   1338
# 3 2019-08-02  B     40      39      221801   1294
# 4 2019-08-03  A     66      60      346854   1845

# %% [markdown]
# Построим графики кумулятивной выручки по дням и группам A/B-тестирования

# %%
# датафрейм с кумулятивным количеством заказов и кумулятивной выручкой по дням в группе А
cumulativeRevenueA = cumulativeData[cumulativeData['group']=='A'][['date','revenue', 'orders']]

# датафрейм с кумулятивным количеством заказов и кумулятивной выручкой по дням в группе B
cumulativeRevenueB = cumulativeData[cumulativeData['group']=='B'][['date','revenue', 'orders']]
fig = plt.subplots(figsize=(12, 5))
# Строим график выручки группы А
plt.plot(cumulativeRevenueA['date'], cumulativeRevenueA['revenue'], label='A')

# Строим график выручки группы B
plt.plot(cumulativeRevenueB['date'], cumulativeRevenueB['revenue'], label='B')
plt.xlabel('дата')
plt.ylabel('кумулятивная выручка')
plt.title('кумулятивная выручка по дням и группам A/B-тестирования')
plt.grid()
plt.legend() 
plt.show()

# %% [markdown]
# Выводы по графику кумулятивной выручки по дням и группа A/B-тестирования:
# 1. кумулятивная выручка увеличивается изо дня в день. Группа В имеет больше заказов начиная с 13 дня.
# 2. на графики есть точки резкого увеличения выручки. Например, 18 день в группе B. Очевидно в это время были сделаны те самые аномально большие заказы. С аномалиями нужно разобраться в дальнейшем.

# %% [markdown]
# ## Построим график кумулятивного среднего чека по группам

# %% [markdown]
# Построим графики среднего чека по группам — разделим кумулятивную выручку на кумулятивное число заказов:

# %%
fig = plt.subplots(figsize=(12, 5))
plt.plot(cumulativeRevenueA['date'], cumulativeRevenueA['revenue']/cumulativeRevenueA['orders'], label='A')
plt.plot(cumulativeRevenueB['date'], cumulativeRevenueB['revenue']/cumulativeRevenueB['orders'], label='B')
plt.xlabel('дата')
plt.ylabel('выручка')
plt.title('средний чек по группам A/B-тестирования')
plt.grid()
plt.legend() 
plt.show()

# %% [markdown]
# Видим, что срений чек приходит в равновесия на 17 день теста, но на 19 день увеличивается почти в два раза в группе В и делает большую разницу между группами. Наверняка все дело в крупных заказах, которые нам не дадут сделать правильный вывод по результатам теста. Также можно отметить, что графики после резкого скачка стремятся друг к другу, это означает, что средний чек выравнивается и группа В теряет свое преимущество заработнное на аномалиях.

# %% [markdown]
# ## Построим график относительного изменения кумулятивного среднего чека группы B к группе A

# %% [markdown]
# Добавим горизонтальную ось методом axhline() (от англ. horizontal line across the axis*, «горизонтальная линия поперек оси»)

# %%
fig = plt.subplots(figsize=(12, 5))
# собираем данные в одном датафрейме
mergedCumulativeRevenue = cumulativeRevenueA.merge(cumulativeRevenueB, left_on='date', right_on='date', how='left', suffixes=['A', 'B'])

# cтроим отношение средних чеков
plt.plot(mergedCumulativeRevenue['date'], (mergedCumulativeRevenue['revenueB']/mergedCumulativeRevenue['ordersB'])/(mergedCumulativeRevenue['revenueA']/mergedCumulativeRevenue['ordersA'])-1)

# добавляем ось X
plt.axhline(y=0, color='black', linestyle='--') 
plt.xlabel('дата')
plt.ylabel('разница в среднем чеке')
plt.title('относительное изменение кумулятивного среднего чека группы B к группе A')
plt.grid()

plt.show()

# %% [markdown]
# Да, действительно в середине теста есть точка, когда группа В резко подскакивает и делает разницу почти в 50%. Имеют место крупые выбросы на 18 день. Без них вероятно изменения кумулятивного среднего чека не было, график понемногу уходит вниз к нулю.

# %% [markdown]
# ## Построим график кумулятивного среднего количества заказов на посетителя по группам.

# %% [markdown]
# Аналогично проанализируем график кумулятивного среднего количества заказов на посетителя по группам. Зададим масштаб осей методом plt.axis(). Передадим ему минимальное и максимальное значения оси x; минимальное и максимальное значения оси y — ["2019-08-01", '2019-08-31', 0, 0.015]:

# %%
fig = plt.subplots(figsize=(12, 5))
# считаем среднее количество заказов на посетителя
cumulativeData['conversion'] = cumulativeData['orders']/cumulativeData['visitors']

# отделяем данные по группе A
cumulativeDataA = cumulativeData[cumulativeData['group']=='A']

# отделяем данные по группе B
cumulativeDataB = cumulativeData[cumulativeData['group']=='B']

# строим графики
plt.plot(cumulativeDataA['date'], cumulativeDataA['conversion'], label='A')
plt.plot(cumulativeDataB['date'], cumulativeDataB['conversion'], label='B')
plt.legend()

# задаем масштаб осей

plt.xlabel('дата')
plt.ylabel('среднее количество заказов на посетителя по группам')
plt.title('график кумулятивного среднего количества заказов на посетителя по группам')
plt.grid()

plt.show()

# %% [markdown]
# В начале теста количество заказов в группе А резко проседает, а уже стабильная разница поддерживается начиная с 9 дня теста. Группа В впереди, пользователи этой группы делали больше заказов. Аномалий, которые привели к разнице не видно. Возможно группа В заработала преимущество без них.

# %% [markdown]
# ## Постройм график относительного изменения кумулятивного среднего количества заказов на посетителя группы B к группе A

# %%
mergedCumulativeConversions = cumulativeDataA[['date','conversion']].merge(cumulativeDataB[['date','conversion']], left_on='date', right_on='date', how='left', suffixes=['A', 'B'])
fig = plt.subplots(figsize=(12, 5))

plt.plot(mergedCumulativeConversions['date'], mergedCumulativeConversions['conversionB']/mergedCumulativeConversions['conversionA']-1, label="Относительный прирост кумулятивного среднего количества заказов на посетителя группы B относительно группы A")


plt.axhline(y=0.1, color='black', linestyle='--')
plt.axhline(y=0.2, color='grey', linestyle='--')
plt.xlabel('дата')
plt.ylabel('отношение кумулятивного среднего количества заказов')
plt.title('график  относительного изменения кумулятивного среднего количества заказов группы B к группе A')
plt.grid()

plt.show()

# %% [markdown]
# В начале теста график колеблется, лидерство держит группа А. На 6 день группа В вырывается вперед и закрепляет свое преимущесво. Начиная с третьего дня теста, пользователи группы В начинают делать больше заказов, и на 15 день разница достигает уровня 20 % и фиксируется в коридоре от 10 до 15%.
#
# Будем исследовать аномалии, возможно влияют на положение линий.

# %% [markdown]
# ## Построим точечный график количества заказов по пользователям.

# %%
#Посчитаем количество заказов каждого пользователя. Для этого создадим сводную таблицу.
ordersByUsers = (
    orders.groupby('userId', as_index=False)
    .agg({'orderId': 'nunique'})
)

ordersByUsers.columns = ['userId', 'orders']

print(ordersByUsers.sort_values(by='orders', ascending=False).head(10))
# Out:
#          userId  orders
# 908  3967698036  3
# 55   249864742   3
# 478  2108163459  3
# 687  2988190573  3
# 890  3908431265  3
# 138  611059232   3
# 632  2742574263  3
# 157  678354126   2
# 323  1404560065  2
# 452  1985475298  2

# %%
x_values = pd.Series(range(0,len(ordersByUsers)))

plt.scatter(x_values, ordersByUsers['orders']) 
plt.xlabel('клиенты')
plt.ylabel('количество заказов')
plt.title('точечная диаграмма числа заказов')
plt.grid()

plt.show()

# %% [markdown]
# Есть клиенты которые совершили по 2-3 заказа, нужно разобраться считать ли их аномалиями. Посчитаем 95 и 99 процентиль и определимся с границей отсеивания.

# %% [markdown]
# ## Посчитаем 95-й и 99-й перцентили количества заказов на пользователя

# %%
np.percentile(ordersByUsers['orders'], [90, 95, 99])
# Out:
# array([1., 1., 2.])

# %% [markdown]
# Подавляющее большинство сделало 1 заказ. Более 2 заказа и более сделали всего 1% клиентов. Выберем границу в 2 заказа и отсеем, кто сделал 3 заказа. Уйдет 8 пользователей.

# %% [markdown]
# ## Построим точечный график стоимостей заказов.

# %%
x_values = pd.Series(range(0,len(orders['revenue'])))
plt.scatter(x_values, orders['revenue']) 

plt.xlabel('клиенты')
plt.ylabel('стоимость заказов')
plt.title('точечная диаграмма стоимости заказов')
plt.grid()

plt.show()

# %% [markdown]
# Видим аномальные значения. 1 очень богатый пользователь сделал заказ стоимостью более 1млн, также есть пользователи с заказами более 100 тыс. Эти покупки искажают результат нашего теста, делая одну из групп прибыльнее. Их нужно исключить. Найдем 95 и 99 процентиль, чтобы определиться с границей.

# %% [markdown]
# ## Посчитаем 95-й и 99-й перцентили стоимости заказов

# %%
np.percentile(orders['revenue'], [90, 95, 99])
# Out:
# array([17990., 26785., 53904.])

# %% [markdown]
# 90% заказов не превышают 17990 рублей. 1 процент делает заказы свыше 53904 рублей.

# %% [markdown]
# Построим диаграмму размаха, чтобы закрепить наши вывыды

# %%
boxplot = orders.boxplot('revenue')
boxplot.set_ylim([0, 20000])
plt.ylabel('выручка с клиента')
plt.title('диаграма размаха выручки с клиента')
plt.show()

# %% [markdown]
# По графику видим, что медианное значение чуть больше 2 500 рублей. В пределах 8 000 рублей находятся 75% процентов заказов. Крупные суммы заказов будут искажать результаты нашего теста.
# Исключим заказы более 25 000 рублей, их совсем немного, от 1 до 5%.

# %% [markdown]
# ## Посчитаем статистическую значимость различий в среднем количестве заказов на посетителя между группами по «сырым» данным.

# %% [markdown]
# Сформулируем гипотезы. Нулевая: различий в среднем количестве заказов между группами нет. Альтернативная: различия в среднем между группами есть.
# Начнём с подготовки данных.

# %%
visitorsADaily = visitors[visitors['group'] == 'A'][['date', 'visitors']]
visitorsADaily.columns = ['date', 'visitorsPerDateA']

visitorsACummulative = visitorsADaily.apply(
    lambda x: visitorsADaily[visitorsADaily['date'] <= x['date']].agg(
        {'date': 'max', 'visitorsPerDateA': 'sum'}
    ),
    axis=1,
)
visitorsACummulative.columns = ['date', 'visitorsCummulativeA']

visitorsBDaily = visitors[visitors['group'] == 'B'][['date', 'visitors']]
visitorsBDaily.columns = ['date', 'visitorsPerDateB']

visitorsBCummulative = visitorsBDaily.apply(
    lambda x: visitorsBDaily[visitorsBDaily['date'] <= x['date']].agg(
        {'date': 'max', 'visitorsPerDateB': 'sum'}
    ),
    axis=1,
)
visitorsBCummulative.columns = ['date', 'visitorsCummulativeB']

ordersADaily = (
    orders[orders['group'] == 'A'][['date', 'orderId', 'userId', 'revenue']]
    .groupby('date', as_index=False)
    .agg({'orderId': pd.Series.nunique, 'revenue': 'sum'})
)
ordersADaily.columns = ['date', 'ordersPerDateA', 'revenuePerDateA']

ordersACummulative = ordersADaily.apply(
    lambda x: ordersADaily[ordersADaily['date'] <= x['date']].agg(
        {'date': 'max', 'ordersPerDateA': 'sum', 'revenuePerDateA': 'sum'}
    ),
    axis=1,
).sort_values(by=['date'])
ordersACummulative.columns = [
    'date',
    'ordersCummulativeA',
    'revenueCummulativeA',
]

ordersBDaily = (
    orders[orders['group'] == 'B'][['date', 'orderId', 'userId', 'revenue']]
    .groupby('date', as_index=False)
    .agg({'orderId': pd.Series.nunique, 'revenue': 'sum'})
)
ordersBDaily.columns = ['date', 'ordersPerDateB', 'revenuePerDateB']

ordersBCummulative = ordersBDaily.apply(
    lambda x: ordersBDaily[ordersBDaily['date'] <= x['date']].agg(
        {'date': 'max', 'ordersPerDateB': 'sum', 'revenuePerDateB': 'sum'}
    ),
    axis=1,
).sort_values(by=['date'])
ordersBCummulative.columns = [
    'date',
    'ordersCummulativeB',
    'revenueCummulativeB',
]

data = (
    ordersADaily.merge(
        ordersBDaily, left_on='date', right_on='date', how='left'
    )
    .merge(ordersACummulative, left_on='date', right_on='date', how='left')
    .merge(ordersBCummulative, left_on='date', right_on='date', how='left')
    .merge(visitorsADaily, left_on='date', right_on='date', how='left')
    .merge(visitorsBDaily, left_on='date', right_on='date', how='left')
    .merge(visitorsACummulative, left_on='date', right_on='date', how='left')
    .merge(visitorsBCummulative, left_on='date', right_on='date', how='left')
)

print(data.head(5))
# Out:
#         date  ordersPerDateA  revenuePerDateA  ordersPerDateB  \
# 0 2019-08-01  23              142779           17
# 1 2019-08-02  19              91602            23
# 2 2019-08-03  24              112473           14
# 3 2019-08-04  11              41176            14
# 4 2019-08-05  22              86383            21
#
#    revenuePerDateB  ordersCummulativeA  revenueCummulativeA  \
# 0  59758            23                  142779
# 1  162043           42                  234381
# 2  67049            66                  346854
# 3  96890            77                  388030
# 4  89908            99                  474413
#
#    ordersCummulativeB  revenueCummulativeB  visitorsPerDateA  \
# 0  17                  59758                719
# 1  40                  221801               619
# 2  54                  288850               507
# 3  68                  385740               717
# 4  89                  475648               756
#
# ...

# %% [markdown]
# Где
# * date — дата;
# * ordersPerDateA — количество заказов в выбранную дату в группе A;
# * revenuePerDateA — суммарная выручка в выбранную дату в группе A;
# * ordersPerDateB — количество заказов в выбранную дату в группе B;
# * revenuePerDateB — суммарная выручка в выбранную дату в группе B;
# * ordersCummulativeA — суммарное число заказов до выбранной даты включительно в группе A;
# * revenueCummulativeA — суммарная выручка до выбранной даты включительно в группе A;
# * ordersCummulativeB — суммарное количество заказов до выбранной даты включительно в группе B;
# * revenueCummulativeB — суммарная выручка до выбранной даты включительно в группе B;
# * visitorsPerDateA — количество пользователей в выбранную дату в группе A;
# * visitorsPerDateB — количество пользователей в выбранную дату в группе B;
# * visitorsCummulativeA — количество пользователей до выбранной даты включительно в группе A;
# * visitorsCummulativeB — количество пользователей до выбранной даты включительно в группе B.

# %% [markdown]
# Посчитаем статистическую значимость различия в среднем количестве заказов между группами.
# Создадим переменные ordersByUsersA и ordersByUsersB со столбцами ['userId', 'orders']. В них для пользователей, которые заказывали хотя бы 1 раз, укажем число совершённых заказов.

# %%
ordersByUsersA = (
    orders[orders['group'] == 'A']
    .groupby('userId', as_index=False)
    .agg({'orderId': pd.Series.nunique})
)
ordersByUsersA.columns = ['userId', 'orders']

ordersByUsersB = (
    orders[orders['group'] == 'B']
    .groupby('userId', as_index=False)
    .agg({'orderId': pd.Series.nunique})
)
ordersByUsersB.columns = ['userId', 'orders']

# %% [markdown]
# Объявим переменные sampleA и sampleB, в которых пользователям из разных групп будет соответствовать количество заказов. Тем, кто ничего не заказал, будут соответствовать нули. Это нужно, чтобы подготовить выборки к проверке критерием Манна-Уитни.

# %%
sampleA = pd.concat([ordersByUsersA['orders'],pd.Series(0, index=np.arange(data['visitorsPerDateA'].sum() - len(ordersByUsersA['orders'])), name='orders')],axis=0)

sampleB = pd.concat([ordersByUsersB['orders'],pd.Series(0, index=np.arange(data['visitorsPerDateB'].sum() - len(ordersByUsersB['orders'])), name='orders')],axis=0)

# %% [markdown]
# Применим критерий и отформатируем p-value, округлив его до трёх знаков после запятой.

# %%
print("p-value равно {0:.3f}".format(st.mannwhitneyu(sampleA, sampleB)[1]))

print("относительная разница между группой В и А равна {0:.3f}".format(sampleB.mean() / sampleA.mean() - 1))
# Out:
# p-value равно 0.011
# относительная разница между группой В и А равна 0.160

# %% [markdown]
# P-value у нас получилось меньше 0,05, значит нулевую гипотезу, что между группами нет статистически значимых различий в среднем числе заказов по сырым данным мы отвергаем.
#
# Относительный выигрыш группы В в размере 16% это подтверждает

# %% [markdown]
# ## Посчитаем статистическую значимость различий в среднем чеке заказа между группами по «сырым» данным.

# %% [markdown]
# Теперь проверим статистическую значимость различий в среднем чеке между сегментами. Нулевая гипотеза: различий в среднем чеке между группами нет. Альтернативная гипотеза: различия в среднем чеке между группами есть.
# Чтобы рассчитать статистическую значимость различий в среднем чеке, передадим критерию mannwhitneyu() данные о выручке с заказов.
# А ещё найдём относительные различия в среднем чеке между группами

# %%
print('p-value равно {0:.3f}'.format(st.mannwhitneyu(orders[orders['group']=='A']['revenue'], orders[orders['group']=='B']['revenue'])[1]))
print('относительные различия в среднем чеке между группами равно {0:.3f}'.format(orders[orders['group']=='B']['revenue'].mean()/orders[orders['group']=='A']['revenue'].mean()-1))
# Out:
# p-value равно 0.829
# относительные различия в среднем чеке между группами равно 0.287

# %% [markdown]
# P-value значительно больше 0.05. Значит, мы не отвергаем нулевую гипотезу - между двумя группами нет статистической значимой разницы в средней сумме чеков. Получившиеся разливчие между группами в 29% произошло из-за выбросов, которые мы в дальнейшем удалим и посмотрим на результат теста еще раз.

# %% [markdown]
# ## Посчитаем статистическую значимость различий в среднем количестве заказов на посетителя между группами по «очищенным» данным

# %% [markdown]
# Мы приняли решение, что клиентов, сделавших более 2 заказов мы отсеем, а также заказы стоимостью дороже 25 000 рублей. Посмотрим к каким выводам мы придем по очищенным данным.

# %% [markdown]
# Сделаем срезы пользователей с числом заказов больше 2 — usersWithManyOrders и пользователей, совершивших заказы дороже 25 000 — usersWithExpensiveOrders. Объединим их в таблице abnormalUsers.

# %%
usersWithManyOrders = pd.concat(
    [
        ordersByUsersA[ordersByUsersA['orders'] > 2]['userId'],
        ordersByUsersB[ordersByUsersB['orders'] > 2]['userId'],
    ],
    axis=0,
)
usersWithExpensiveOrders = orders[orders['revenue'] > 25000]['userId']
abnormalUsers = (
    pd.concat([usersWithManyOrders, usersWithExpensiveOrders], axis=0)
    .drop_duplicates()
    .sort_values()
)
print(abnormalUsers.head(5))
print(abnormalUsers.shape[0])
# Out:
# 568     113298937
# 1099    148427295
# 461     154576532
# 928     204675465
# 33      249864742
# Name: userId, dtype: int64
# 65

# %% [markdown]
# Анамальных пользователей у нас получилось 65.

# %% [markdown]
# Сформулируем гипотезы. Нулевая: различий в среднем количестве заказов между группами нет. Альтернативная: различия в среднем между группами есть. Теперь посмотрим какие результаты даст тест по очищенным данным. Сначала подготовим выборки количества заказов по пользователям по группам теста:

# %%
sampleAFiltered = pd.concat(
    [
        ordersByUsersA[
            np.logical_not(ordersByUsersA['userId'].isin(abnormalUsers))
        ]['orders'],
        pd.Series(
            0,
            index=np.arange(
                data['visitorsPerDateA'].sum() - len(ordersByUsersA['orders'])
            ),
            name='orders',
        ),
    ],
    axis=0,
)

sampleBFiltered = pd.concat(
    [
        ordersByUsersB[
            np.logical_not(ordersByUsersB['userId'].isin(abnormalUsers))
        ]['orders'],
        pd.Series(
            0,
            index=np.arange(
                data['visitorsPerDateB'].sum() - len(ordersByUsersB['orders'])
            ),
            name='orders',
        ),
    ],
    axis=0,
)

# %%
print('p-value равно {0:.3f}'.format(st.mannwhitneyu(sampleAFiltered, sampleBFiltered)[1]))
print('относительный разница между группой В и А {0:.3f}'.format(sampleBFiltered.mean()/sampleAFiltered.mean()-1))
# Out:
# p-value равно 0.019
# относительный разница между группой В и А 0.171

# %% [markdown]
# Результат почти не изменился. Сырые данные по количеству пользователей были и без того достаточно качественные. Мы удалили всего несколько пользователей с 3 заказами, они не повлияли на результат. Отвергаем нулевую гипотезу.

# %% [markdown]
# ## Посчитаем статистическую значимость различий в среднем чеке заказа между группами по «очищенным» данным

# %% [markdown]
# Сформируем гипотезы для теста с очищенными данными. Нулевая гипотеза: различий в среднем чеке между группами нет. Альтернативная гипотеза: различия в среднем чеке между группами есть. Аномалии мы уже отсеили смотрим на новый результат теста.

# %%
print(
    'p-value равно  {0:.3f}'.format(
        st.mannwhitneyu(
            orders[
                np.logical_and(
                    orders['group'] == 'A',
                    np.logical_not(orders['userId'].isin(abnormalUsers)),
                )
            ]['revenue'],
            orders[
                np.logical_and(
                    orders['group'] == 'B',
                    np.logical_not(orders['userId'].isin(abnormalUsers)),
                )
            ]['revenue'],
        )[1]
    )
)

print(
    "относительные различия в среднем чеке между группами равно {0:.3f}".format(
        orders[
            np.logical_and(
                orders['group'] == 'B',
                np.logical_not(orders['userId'].isin(abnormalUsers)),
            )
        ]['revenue'].mean()
        / orders[
            np.logical_and(
                orders['group'] == 'A',
                np.logical_not(orders['userId'].isin(abnormalUsers)),
            )
        ]['revenue'].mean()
        - 1
    )
)
# Out:
# p-value равно  0.475
# относительные различия в среднем чеке между группами равно -0.088

# %% [markdown]
# Результаты теста по очищенным данным отличаются значительно! P-value хоть и значительно больше 5%, уменьшился с 82% до 47%. А различия в среднем чеке сгладилось до 9%, но уже в пользу группы А, а было 29% с перевесом в группе В.
#
# Но мы, конечно, также не отвергаем нулевую гипотезу. Статистически значимых различий по среднему чеку между группами нет.

# %% [markdown]
# ## Выводы по проекту и рекомендации.

# %% [markdown]
# В данном проекте мы провели интересное исследование.
# Выступая в качестве аналитика, мы:
# - получили данные с гипотезами и параметрами Reach, Impact, Confidence, Effort. Воспользовавшись методиками ICE и RICE для приоритизации гипотез, мы определили, что самая привлекательная из них это - **добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок**. Она выглядит наиболее сбалансированно, будет влиять на всех пользователей, и влиять достаточно сильно, в чем мы уверены. Ее реализация будет стоить определенным ресурсов, но не таких больших, чтобы она не окупилась. Кроме лидирующей по оценкам гипотезы, можно выделить гипотезу **добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средний чек заказа**, **добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей**, **показать на главной странице баннеры с актуальными акциями и распродажами, чтобы увеличить конверсию**. Они получили увесистые оценки в обоих способах.
# - Также мы получили датафреймы с результатами А/В-теста. Изучили данные и провели предобработку. Проверили на дубликаты и пропуски, заметили аномальные значения, привели впорядок название столбцов, а также нашли клиентов, которые попадают в обе группы. Такого быть не должно и мы исключили этих клиентов из дальнейшего исследования, т.к. способа опредить к какой группе они точно относятся у нас не имеется. В дальнейшем мы строили графики кумулятивных показателей. Выяснили что:
#     - На графиках кумулятивной выручки по группам есть точки резкого увеличения выручки. Например, 18 день в группе B. Очевидно в это время были сделаны те самые аномально большие заказы, также можно выделить причину, что в группе В было больше заказов. С аномалиями нужно разобраться в дальнейшем.
#     - По графику кумулятивного среднего чека по группам увидили, что срений чек приходит в равновесия на 17 день теста, но на 19 день увеличивается почти в два раза в группе В и делает большую разницу между группами. Все дело в аномальных заказах.
#     - По графику относительного изменения кумулятивного среднего чека, подтвердили свой вывод о крупных закзов в группе В, которые делают разницу в среднем чеке. После скачка график спускается к нулю
#     - График кумулятивного количества заказов дал нам понять, что в группе В значительно больше заказов.
#     - Начиная с третьего дня теста, пользователи группы В начинают делать больше заказов и на 15 день разница фиксируется на уровне 20 %.
#     - Всего 1% пользователей делает 2 и более заказов. Мы определили границу отсеивания как 3 заказа одного пользователя.
#     - Выбросов связанных со стоимостью заказов куда больше. Есть заказ улетевший в небеса на графиках, его стоимость более 1 млн рублей, этот заказ и повлиял на наши графики и сделал разницу группе В. Мы приняли решения в чистых данных, отказаться от заказов от 25 000 рублей. Эти заказы составляют от 1до 5% от общего количества.
#
# Далее мы подготовили выборки к проверке критерием Манна-Уитни. Начали с сырых данных. Выдвигали следующие гипотезы:
# - Нулевая: различий в среднем количестве заказов между группами нет. Альтернативная: различия в среднем между группами есть. p-value получилось - 0.011, относительный выигрыш группы В равен 0.160. P-value  меньше 0,05, значит нулевую гипотезу, что между группами нет статистически значимых различий в среднем числе заказов по сырым данным мы отвергаем.
# Относительный проигрыш группы В в размере 16% это подтверждает
# - Нулевая гипотеза: различий в среднем чеке между группами нет. Альтернативная гипотеза: различия в среднем чеке между группами есть. p-value равно 0.829. Относительные различия в среднем чеке между группами равно 0.287. P-value значительно больше 0.05. Значит, причин отвергать нулевую гипотезу и считать, что в среднем чеке есть различия, нет. Впрочем, средний чек группы B значительно больше среднего чека группы A на 29%.
# Далее занялись очищенными данными:
# - Нулевая: различий в среднем количестве заказов между группами нет. Альтернативная: различия в среднем между группами есть.p-value равно 0.019. Относительный выигрыш группы В равен 0.171. Результат почти не изменился. Сырые данные по количеству пользователей были и без того достаточно качественные. Мы удалили всего несколько пользователей с 3 заказами, они не повлияли на результат. Отвергаем нулевую гипотезу.
# - Нулевая гипотеза: различий в среднем чеке между группами нет. Альтернативная гипотеза: различия в среднем чеке между группами есть. p-value равно  0.475, относительные различия в среднем чеке между группами равно -0.088.Результаты теста по очищенным данным отличаются значительно! P-value хоть и значительно больше 5%, уменьшился с 82% до 47%. А различия в среднем чеке сгладилось до 9%, но уже в пользу группы А, а было 29% с перевесом в группе В. Но, статистически значимых различий по среднему чеку между группами нет, нулевую гипотезу мы не отвергаем.
#
# **Вывод по проведенному тесту:**
# 1. Есть статическое значимое различие между группой В и А по среднему количеству заказов, и она в пользу В, как по очищенным, так и по сырым данным. Относительным выигрыш по очищенным данным равен 17%
# 2. По графику относительного изменения кумулятивного среднего количества заказов на посетителя группы B к группе A, мы видим, что группа В приносит стабильно больше заказов и группа А не может ее догнать.
# 3. По среднему чеку различий, тем более когда мы отсеили аномалии, нет. В группах делаются одинаковые по стоимости заказы. График относительного изменения куммулятивного среднего чека группы B к группе A, после выброса сглаживается.
#
# **Исходя из обнаруженных фактов, тест следует остановить и признать успешным. Сегмент клиентов в группе делает более частые покупки, хотя и по цене они не отличаются, клиенты группы B будут приносить на 17% больше выручки**
